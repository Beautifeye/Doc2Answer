# %%
import os
import pandas as pd
import cv2
import json
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', None)

# %%
IMAGES_DIR = '/home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/'
ANNOTATIONS_DIR = '/home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerBoxes/'
# SAMPLES_FILE = 'sample-frames-to-annotate/samples.pkl'

# %%
dataset = json.load(open('../annotated_matched_boxes.json'))

# %%
ann_dict = {'name':[], 'path':[], 'points':[], 'box_id':[]}
for k, v in dataset.items():
    for shape in v['retrieved_boxes']:
        ann_dict['name'].append(k)
        ann_dict['path'].append(v['img_path'])
        ann_dict['points'].append(tuple(np.round(shape['box']).astype(int)))
        ann_dict['box_id'].append(shape['box_id'])

ann_df = pd.DataFrame(ann_dict)
ann_df.head(3)
# Out:
#          name  \
# 0  100849_10b
# 1  100849_10b
# 2  100849_10b
#
#                                                                                                          path  \
# 0  /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# 1  /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# 2  /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
#
#                    points  box_id
# 0  (285, 1010, 481, 1213)       1
# 1   (881, 300, 1074, 483)       2
# 2   (103, 998, 299, 1201)       1

# %%
N_SAMPLES = 2
for _, row in ann_df.sample(N_SAMPLES).iterrows():
    
    img_path = row['path']
    x1, y1, x2, y2 = row['points']
    
    im = cv2.imread(img_path)
    cv2.rectangle(im, (x1, y1), (x2, y2), (0,0,255), 5)
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# %%
ann_df.name.nunique(), ann_df.groupby('name').size().mean()
# Out:
# (811, 44.24537607891492)

# %%
from sklearn.model_selection import train_test_split

TEST_RATIO = 0.15
np.random.seed(314)
cards = sorted(ann_df.name.unique())
train_cards, test_cards = train_test_split(cards, test_size=TEST_RATIO, random_state=314)

# %%
train_df = ann_df[ann_df['name'].isin(train_cards)]
test_df  = ann_df[ann_df['name'].isin(test_cards)]

train_df = train_df.reset_index().drop('index', axis=1)
test_df = test_df.reset_index().drop('index', axis=1)

display(train_df)
display(test_df)


train_df.to_pickle('train_df.pkl')
test_df.to_pickle('test_df.pkl')
# Out:
#              name  \
# 0      100849_10b
# 1      100849_10b
# 2      100849_10b
# 3      100849_10b
# 4      100849_10b
# ...           ...
# 30994     Image 6
# 30995     Image 6
# 30996     Image 6
# 30997     Image 6
# 30998     Image 6
#
#                                                                                                              path  \
# 0      /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# 1      /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# 2      /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# 3      /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# 4      /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg
# ...                                                                                                           ...
# 30994     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_6b.jpg
# 30995     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_6b.jpg
# 30996     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_6b.jpg
# 30997     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_6b.jpg
# 30998     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_6b.jpg
#
#                        points  box_id
# 0      (285, 1010, 481, 1213)       1
# 1       (881, 300, 1074, 483)       2
# 2       (103, 998, 299, 1201)       1
# 3      (1066, 299, 1259, 482)       2
# 4       (870, 484, 1063, 667)       2
# ...                       ...     ...
# 30994    (149, 502, 336, 687)       1
# 30995    (333, 499, 520, 684)       1
# 30996    (156, 321, 343, 506)       1
# 30997   (902, 312, 1089, 497)       1
# 30998    (339, 318, 526, 503)       1
#
# [30999 rows x 4 columns]
#           name  \
# 0     10231_9b
# 1     10231_9b
# 2     10231_9b
# 3     10231_9b
# 4     10231_9b
# ...        ...
# 4879   Image 3
# 4880   Image 3
# 4881   Image 3
# 4882   Image 3
# 4883   Image 3
#
#                                                                                                           path  \
# 0     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/10231_9b.jpg
# 1     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/10231_9b.jpg
# 2     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/10231_9b.jpg
# 3     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/10231_9b.jpg
# 4     /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/10231_9b.jpg
# ...                                                                                                        ...
# 4879   /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_3b.jpg
# 4880   /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_3b.jpg
# 4881   /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_3b.jpg
# 4882   /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_3b.jpg
# 4883   /home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/1424_3b.jpg
#
#                       points  box_id
# 0       (372, 164, 558, 344)       1
# 1       (544, 512, 726, 702)       2
# 2      (536, 872, 726, 1068)       3
# 3       (194, 168, 380, 349)       1
# 4       (359, 690, 545, 871)       1
# ...                      ...     ...
# 4879    (405, 692, 623, 939)       2
# 4880   (828, 691, 1046, 938)       2
# 4881  (1071, 196, 1289, 443)       2
# 4882    (198, 694, 416, 941)       2
# 4883   (184, 944, 402, 1191)       2
#
# [4884 rows x 4 columns]

# %%
ann_df = pd.read_pickle('train_df.pkl')

# %%
img_path = '/home/ubuntu/storage/Doc2Answer/download_from_drive/data/ProcessedCards/ProcessedInnerCards/100849_10b.jpg'
boxes = ann_df.loc[ann_df.path==img_path, 'points'].apply(np.array).values
boxes = np.stack(boxes)

# %%
ann_df.name.nunique(), ann_df.path.apply(lambda x: x.split('/')[-1]).nunique()
# Out:
# (689, 682)

# %%
sorted(ann_df.groupby('path').name.unique(), key=lambda x: len(x), reverse=1)
# Out:
# [array(['10231_2b', 'Image 14'], dtype=object),
#  array(['10231_3b', 'Image 15'], dtype=object),
#  array(['10231_5b', 'Image 17'], dtype=object),
#  array(['10231_6b', 'Image 18'], dtype=object),
#  array(['10423_2b', 'Image 23'], dtype=object),
#  array(['10423_3b', 'Image 24'], dtype=object),
#  array(['10423_7b', 'Image 28'], dtype=object),
#  array(['100849_10b'], dtype=object),
#  array(['100849_7b'], dtype=object),
#  array(['100849_8b'], dtype=object),
#  array(['100849_9b'], dtype=object),
#  array(['101342_3b'], dtype=object),
#  array(['101342_4b'], dtype=object),
#  array(['101342_5b'], dtype=object),
#  array(['101342_6b'], dtype=object),
#  array(['10231_1b'], dtype=object),
#  array(['10231_4b'], dtype=object),
#  array(['10231_7b'], dtype=object),
#  array(['10231_8b'], dtype=object),
#  array(['Image 21'], dtype=object),
#  array(['103445_10b'], dtype=object),
#  array(['103445_11b'], dtype=object),
#  array(['103445_12b'], dtype=object),
#  array(['103445_13b'], dtype=object),
#  array(['103445_14b'], dtype=object),
#  array(['103445_8b'], dtype=object),
#  array(['103445_9b'], dtype=object),
#  array(['10423_1917_b'], dtype=object),
#  array(['10423_1918_b'], dtype=object),
#  array(['10423_1b'], dtype=object),
#  array(['10423_4b'], dtype=object),
#  array(['Image 26'], dtype=object),
#  array(['10423_6b'], dtype=object),
#  array(['Image 29'], dtype=object),
#  array(['10423_9b'], dtype=object),
#  array(['105281_11b'], dtype=object),
#  array(['105281_13b'], dtype=object),
#  array(['105281_1918_b'], dtype=object),
#  array(['105281_6b'], dtype=object),
#  array(['105281_7b'], dtype=object),
#  array(['105281_8b'], dtype=object),
#  array(['105281_9b'], dtype=object),
#  array(['10927_1917_b'], dtype=object),
#  array(['10927_2b'], dtype=object),
#  array(['10927_3b'], dtype=object),
#  array(['10927_4b'], dtype=object),
#  array(['10927_5b'], dtype=object),
#  array(['10927_6b'], dtype=object),
#  array(['11367_1b'], dtype=object),
#  array(['11367_2b'], dtype=object),
#  array(['11367_3BISb'], dtype=object),
#  array(['11367_3b'], dtype=object),
#  array(['11367_4b'], dtype=object),
#  array(['11367_5b'], dtype=object),
#  array(['11815_4b'], dtype=object),
#  array(['11815_5b'], dtype=object),
#  array(['11815_7b'], dtype=object),
#  array(['11816_1b'], dtype=object),
#  array(['11816_2b'], dtype=object),
#  array(['11816_4b'], dtype=object),
#  array(['11816_5b'], dtype=object),
#  array(['11816_6b'], dtype=object),
#  array(['11816_7b'], dtype=object),
#  array(['11816_8b'], dtype=object),
#  array(['11818_1b'], dtype=object),
#  array(['11818_2b'], dtype=object),
#  array(['11818_5b'], dtype=object),
#  array(['11818_6b'], dtype=object),
#  array(['11818_7b'], dtype=object),
#  array(['11821_1b'], dtype=object),
#  array(['11821_2b'], dtype=object),
#  array(['11821_3b'], dtype=object),
#  array(['11821_4b'], dtype=object),
#  array(['11821_5b'], dtype=object),
#  array(['11821_6b'], dtype=object),
#  array(['11821_7b'], dtype=object),
#  array(['11823_1b'], dtype=object),
#  array(['11823_3b'], dtype=object),
#  array(['11823_4b'], dtype=object),
#  array(['11823_5b'], dtype=object),
#  array(['11823_6b'], dtype=object),
#  array(['11823_7b'], dtype=object),
#  array(['11824_1918_b'], dtype=object),
#  array(['11824_1b'], dtype=object),
#  array(['11824_2b'], dtype=object),
#  array(['11824_3b'], dtype=object),
#  array(['11824_4b'], dtype=object),
#  array(['11824_5b'], dtype=object),
#  array(['11824_6b'], dtype=object),
#  array(['11824_7b'], dtype=object),
#  array(['11826_1b'], dtype=object),
#  array(['11826_3b'], dtype=object),
#  array(['11826_4b'], dtype=object),
#  array(['11826_5b'], dtype=object),
#  array(['11826_6b'], dtype=object),
#  array(['11826_7b'], dtype=object),
#  array(['11826_8b'], dtype=object),
#  array(['11827_1b'], dtype=object),
#  array(['11827_2b'], dtype=object),
#  array(['11827_3b'], dtype=object),
#  array(['11827_4b'], dtype=object),
#  array(['11827_5b'], dtype=object),
#  array(['11827_6b'], dtype=object),
#  array(['11828_1b'], dtype=object),
#  array(['11828_3b'], dtype=object),
#  array(['11828_4b'], dtype=object),
#  array(['11828_5b'], dtype=object),
#  array(['11828_6b'], dtype=object),
#  array(['11829_1b'], dtype=object),
#  array(['11829_3b'], dtype=object),
#  array(['11829_4b'], dtype=object),
#  array(['11829_5b'], dtype=object),
#  array(['11830_1917_b'], dtype=object),
#  array(['11830_1b'], dtype=object),
#  array(['11830_2b'], dtype=object),
#  array(['11830_4b'], dtype=object),
#  array(['11830_5b'], dtype=object),
#  array(['11830_6b'], dtype=object),
#  array(['11830_7b'], dtype=object),
#  array(['11831_10b'], dtype=object),
#  array(['11831_1b'], dtype=object),
#  array(['11831_2b'], dtype=object),
#  array(['11831_3b'], dtype=object),
#  array(['11831_4b'], dtype=object),
#  array(['11831_5b'], dtype=object),
#  array(['11831_6b'], dtype=object),
#  array(['11831_7b'], dtype=object),
#  array(['11831_8b'], dtype=object),
#  array(['11831_9b'], dtype=object),
#  array(['11834_1b'], dtype=object),
#  array(['11834_2b'], dtype=object),
#  array(['11834_3b'], dtype=object),
#  array(['11834_5b'], dtype=object),
#  array(['11834_6b'], dtype=object),
#  array(['11835_1b'], dtype=object),
#  array(['11835_3b'], dtype=object),
#  array(['11835_4b'], dtype=object),
#  array(['11835_5b'], dtype=object),
#  array(['11835_6b'], dtype=object),
#  array(['11835_7b'], dtype=object),
#  array(['11839_4b'], dtype=object),
#  array(['11839_5b'], dtype=object),
#  array(['11840_1917_b'], dtype=object),
#  array(['11840_1b'], dtype=object),
#  array(['11840_2b'], dtype=object),
#  array(['11840_3b'], dtype=object),
#  array(['11840_4b'], dtype=object),
#  array(['11840_6b'], dtype=object),
#  array(['11840_7b'], dtype=object),
#  array(['11916_1b'], dtype=object),
#  array(['11916_2b'], dtype=object),
#  array(['11916_3b'], dtype=object),
#  array(['11916_4b'], dtype=object),
#  array(['11916_5b'], dtype=object),
#  array(['11916_6b'], dtype=object),
#  array(['12502_2b'], dtype=object),
#  array(['12502_3b'], dtype=object),
#  array(['12502_4b'], dtype=object),
#  array(['12502_5b'], dtype=object),
#  array(['12502_6b'], dtype=object),
#  array(['12502_7b'], dtype=object),
#  array(['13425_10b'], dtype=object),
#  array(['13425_11b'], dtype=object),
#  array(['13425_12b'], dtype=object),
#  array(['13425_8b'], dtype=object),
#  array(['13745_2b'], dtype=object),
#  array(['13745_3b'], dtype=object),
#  array(['13745_4b'], dtype=object),
#  array(['13745_5b'], dtype=object),
#  array(['13745_6b'], dtype=object),
#  array(['13745_8b'], dtype=object),
#  array(['13745_9b'], dtype=object),
#  array(['14233_1b'], dtype=object),
#  array(['14233_2b'], dtype=object),
#  array(['14233_3b'], dtype=object),
#  array(['14233_4b'], dtype=object),
#  array(['14233_5b'], dtype=object),
#  array(['14233_6b'], dtype=object),
#  array(['14234_1b'], dtype=object),
#  array(['14234_2b'], dtype=object),
#  array(['14234_3b'], dtype=object),
#  array(['14234_4b'], dtype=object),
#  array(['14234_5b'], dtype=object),
#  array(['14234_6b'], dtype=object),
#  array(['14236_1b'], dtype=object),
#  array(['14236_2b'], dtype=object),
#  array(['14236_3b'], dtype=object),
#  array(['14236_4b'], dtype=object),
#  array(['14236_7b'], dtype=object),
#  array(['Image 1'], dtype=object),
#  array(['Image 2'], dtype=object),
#  array(['Image 4'], dtype=object),
#  array(['Image 5'], dtype=object),
#  array(['Image 6'], dtype=object),
#  array(['Image 7'], dtype=object),
#  array(['Image 8'], dtype=object),
#  array(['Image 10'], dtype=object),
#  array(['Image 11'], dtype=object),
#  array(['Image 12'], dtype=object),
#  array(['23132_6b'], dtype=object),
#  array(['23132_8b'], dtype=object),
#  array(['23132_9b'], dtype=object),
#  array(['23297_2b'], dtype=object),
#  array(['23297_3b'], dtype=object),
#  array(['23297_4b'], dtype=object),
#  array(['23297_5b'], dtype=object),
#  array(['23297_6b'], dtype=object),
#  array(['23297_8b'], dtype=object),
#  array(['23297_9b'], dtype=object),
#  array(['26488_1b'], dtype=object),
#  array(['26488_2b'], dtype=object),
#  array(['26488_3b'], dtype=object),
#  array(['26488_4b'], dtype=object),
#  array(['26488_5b'], dtype=object),
#  array(['31002_1917_b'], dtype=object),
#  array(['31002_1918__b'], dtype=object),
#  array(['31002_1b'], dtype=object),
#  array(['31002_3b'], dtype=object),
#  array(['31002_4b'], dtype=object),
#  array(['31002_6b'], dtype=object),
#  array(['31002_7b'], dtype=object),
#  array(['31010_1b'], dtype=object),
#  array(['31010_2b'], dtype=object),
#  array(['31010_3b'], dtype=object),
#  array(['31010_4b'], dtype=object),
#  array(['31010_5b'], dtype=object),
#  array(['31010_6b'], dtype=object),
#  array(['31010_7b'], dtype=object),
#  array(['31083_1b'], dtype=object),
#  array(['31083_2b'], dtype=object),
#  array(['31083_4b'], dtype=object),
#  array(['31083_5b'], dtype=object),
#  array(['31083_6b'], dtype=object),
#  array(['32037_6b'], dtype=object),
#  array(['32037_8b'], dtype=object),
#  array(['32208_1917_b'], dtype=object),
#  array(['32208_1918_b'], dtype=object),
#  array(['32208_1b'], dtype=object),
#  array(['32208_2b'], dtype=object),
#  array(['32208_3b'], dtype=object),
#  array(['32208_4b'], dtype=object),
#  array(['32208_5b'], dtype=object),
#  array(['32208_7b'], dtype=object),
#  array(['33332_10b'], dtype=object),
#  array(['33332_1b'], dtype=object),
#  array(['33332_2b'], dtype=object),
#  array(['33332_3b'], dtype=object),
#  array(['33332_5b'], dtype=object),
#  array(['33332_6b'], dtype=object),
#  array(['33332_7b'], dtype=object),
#  array(['33332_8b'], dtype=object),
#  array(['33332_9b'], dtype=object),
#  array(['34113_2b'], dtype=object),
#  array(['34113_3b'], dtype=object),
#  array(['34113_4b'], dtype=object),
#  array(['34113_6b'], dtype=object),
#  array(['54500_10b'], dtype=object),
#  array(['54500_1918_b'], dtype=object),
#  array(['54500_3b'], dtype=object),
#  array(['54500_4b'], dtype=object),
#  array(['54500_5b'], dtype=object),
#  array(['54500_6b'], dtype=object),
#  array(['54500_7b'], dtype=object),
#  array(['54500_8b'], dtype=object),
#  array(['54500_9b'], dtype=object),
#  array(['54915_1b'], dtype=object),
#  array(['54915_2b'], dtype=object),
#  array(['54915_3b'], dtype=object),
#  array(['54915_4b'], dtype=object),
#  array(['54915_5b'], dtype=object),
#  array(['54915_6b'], dtype=object),
#  array(['54921_1b'], dtype=object),
#  array(['54921_2b'], dtype=object),
#  array(['54921_3b'], dtype=object),
#  array(['54921_4b'], dtype=object),
#  array(['54925_2b'], dtype=object),
#  array(['54925_3b'], dtype=object),
#  array(['54925_4b'], dtype=object),
#  array(['54925_5b'], dtype=object),
#  array(['54925_6b'], dtype=object),
#  array(['54925_7b'], dtype=object),
#  array(['54925_8b'], dtype=object),
#  array(['55120_1b'], dtype=object),
#  array(['55120_2b'], dtype=object),
#  array(['55120_4b'], dtype=object),
#  array(['55120_5b'], dtype=object),
#  array(['55120_7b'], dtype=object),
#  array(['55120_8b'], dtype=object),
#  array(['55120_9b'], dtype=object),
#  array(['55314_1b'], dtype=object),
#  array(['55314_2b'], dtype=object),
#  array(['55314_3b'], dtype=object),
#  array(['55314_5b'], dtype=object),
#  array(['55314_6b'], dtype=object),
#  array(['55314_7b'], dtype=object),
#  array(['55314_8b'], dtype=object),
#  array(['55314_9b'], dtype=object),
#  array(['55351_1b'], dtype=object),
#  array(['55351_2b'], dtype=object),
#  array(['55351_3b'], dtype=object),
#  array(['55351_4b'], dtype=object),
#  array(['55351_5b'], dtype=object),
#  array(['55351_6b'], dtype=object),
#  array(['55351_7b'], dtype=object),
#  array(['55351_8b'], dtype=object),
#  array(['55586_2b'], dtype=object),
#  array(['55586_3b'], dtype=object),
#  array(['55586_4b'], dtype=object),
#  array(['55586_5b'], dtype=object),
#  array(['55586_6b'], dtype=object),
#  array(['55589_10b'], dtype=object),
#  array(['55589_11b'], dtype=object),
#  array(['55589_1b'], dtype=object),
#  array(['55589_2b'], dtype=object),
#  array(['55589_3b'], dtype=object),
#  array(['55589_5b'], dtype=object),
#  array(['55589_6b'], dtype=object),
#  array(['55589_7b'], dtype=object),
#  array(['55589_8b'], dtype=object),
#  array(['56328_10b'], dtype=object),
#  array(['56328_1b'], dtype=object),
#  array(['56328_4b'], dtype=object),
#  array(['56328_5b'], dtype=object),
#  array(['56328_6b'], dtype=object),
#  array(['56328_7b'], dtype=object),
#  array(['56328_9b'], dtype=object),
#  array(['56330_10b'], dtype=object),
#  array(['56330_2b'], dtype=object),
#  array(['56330_3b'], dtype=object),
#  array(['56330_4b'], dtype=object),
#  array(['56330_5b'], dtype=object),
#  array(['56330_6b'], dtype=object),
#  array(['56330_7b'], dtype=object),
#  array(['56330_8b'], dtype=object),
#  array(['56330_9b'], dtype=object),
#  array(['56735_10b'], dtype=object),
#  array(['56735_1b'], dtype=object),
#  array(['56735_3b'], dtype=object),
#  array(['56735_4b'], dtype=object),
#  array(['56735_5b'], dtype=object),
#  array(['56735_6b'], dtype=object),
#  array(['56735_7b'], dtype=object),
#  array(['56735_8b'], dtype=object),
#  array(['56735_9b'], dtype=object),
#  array(['56749_10b'], dtype=object),
#  array(['56749_1b'], dtype=object),
#  array(['56749_2b'], dtype=object),
#  array(['56749_3b'], dtype=object),
#  array(['56749_4b'], dtype=object),
#  array(['56749_5b'], dtype=object),
#  array(['56749_6b'], dtype=object),
#  array(['56749_7b'], dtype=object),
#  array(['64986_7b'], dtype=object),
#  array(['65099_1b'], dtype=object),
#  array(['65099_2BISb'], dtype=object),
#  array(['65099_2b'], dtype=object),
#  array(['65099_4b'], dtype=object),
#  array(['65099_5b'], dtype=object),
#  array(['65099_6b'], dtype=object),
#  array(['65099_8b'], dtype=object),
#  array(['65099_9b'], dtype=object),
#  array(['65282_1b'], dtype=object),
#  array(['65282_2b'], dtype=object),
#  array(['65282_3b'], dtype=object),
#  array(['65282_4b'], dtype=object),
#  array(['65282_5b'], dtype=object),
#  array(['65282_6b'], dtype=object),
#  array(['65282_7b'], dtype=object),
#  array(['65282_8b'], dtype=object),
#  array(['65556_10b'], dtype=object),
#  array(['65556_1917_b'], dtype=object),
#  array(['65556_1918_b'], dtype=object),
#  array(['65556_1b'], dtype=object),
#  array(['65556_3b'], dtype=object),
#  array(['65556_4b'], dtype=object),
#  array(['65556_5b'], dtype=object),
#  array(['65556_6b'], dtype=object),
#  array(['65556_7b'], dtype=object),
#  array(['65556_8b'], dtype=object),
#  array(['65683_1b'], dtype=object),
#  array(['65683_2b'], dtype=object),
#  array(['65683_3b'], dtype=object),
#  array(['65683_4b'], dtype=object),
#  array(['65683_5b'], dtype=object),
#  array(['65683_6b'], dtype=object),
#  array(['65683_7b'], dtype=object),
#  array(['66113_1917_b'], dtype=object),
#  array(['66113_1918_b'], dtype=object),
#  array(['66113_1b'], dtype=object),
#  array(['66113_2b'], dtype=object),
#  array(['66113_3b'], dtype=object),
#  array(['66113_5b'], dtype=object),
#  array(['66113_6b'], dtype=object),
#  array(['66113_7b'], dtype=object),
#  array(['66113_8b'], dtype=object),
#  array(['66113_9b'], dtype=object),
#  array(['66394_1917_b'], dtype=object),
#  array(['66394_1b'], dtype=object),
#  array(['66394_2b'], dtype=object),
#  array(['66394_4b'], dtype=object),
#  array(['66394_5b'], dtype=object),
#  array(['66394_6b'], dtype=object),
#  array(['66394_7b'], dtype=object),
#  array(['66394_9b'], dtype=object),
#  array(['66439_1917_b'], dtype=object),
#  array(['66439_1b'], dtype=object),
#  array(['66439_2b'], dtype=object),
#  array(['66439_3b'], dtype=object),
#  array(['66439_4b'], dtype=object),
#  array(['66439_5b'], dtype=object),
#  array(['66439_6b'], dtype=object),
#  array(['66439_8b'], dtype=object),
#  array(['66439_9b'], dtype=object),
#  array(['66463_10b'], dtype=object),
#  array(['66463_11b'], dtype=object),
#  array(['66463_1b'], dtype=object),
#  array(['66463_2b'], dtype=object),
#  array(['66463_4b'], dtype=object),
#  array(['66463_5b'], dtype=object),
#  array(['66463_6b'], dtype=object),
#  array(['66463_7b'], dtype=object),
#  array(['66463_8b'], dtype=object),
#  array(['66599_10b'], dtype=object),
#  array(['66599_11b'], dtype=object),
#  array(['66599_1918_b'], dtype=object),
#  array(['66599_3b'], dtype=object),
#  array(['66599_4b'], dtype=object),
#  array(['66599_5b'], dtype=object),
#  array(['66599_6b'], dtype=object),
#  array(['66599_7b'], dtype=object),
#  array(['66599_8b'], dtype=object),
#  array(['66599_9b'], dtype=object),
#  array(['67648_1b'], dtype=object),
#  array(['67648_2b'], dtype=object),
#  array(['67648_3b'], dtype=object),
#  array(['67648_5b'], dtype=object),
#  array(['67648_6b'], dtype=object),
#  array(['67648_7b'], dtype=object),
#  array(['67648_8b'], dtype=object),
#  array(['67888_10b'], dtype=object),
#  array(['67888_11b'], dtype=object),
#  array(['67888_1b'], dtype=object),
#  array(['67888_2b'], dtype=object),
#  array(['67888_3b'], dtype=object),
#  array(['67888_4b'], dtype=object),
#  array(['67888_5b'], dtype=object),
#  array(['67888_7b'], dtype=object),
#  array(['67888_8b'], dtype=object),
#  array(['67965_1b'], dtype=object),
#  array(['67965_2b'], dtype=object),
#  array(['67965_3b'], dtype=object),
#  array(['67965_4b'], dtype=object),
#  array(['67965_5b'], dtype=object),
#  array(['67965_6b'], dtype=object),
#  array(['68120_1b'], dtype=object),
#  array(['68120_2b'], dtype=object),
#  array(['68120_3b'], dtype=object),
#  array(['68120_4b'], dtype=object),
#  array(['68120_5b'], dtype=object),
#  array(['68120_6b'], dtype=object),
#  array(['68120_7b'], dtype=object),
#  array(['68120_8b'], dtype=object),
#  array(['68120_9b'], dtype=object),
#  array(['68130_10b'], dtype=object),
#  array(['68130_11b'], dtype=object),
#  array(['68130_1b'], dtype=object),
#  array(['68130_2b'], dtype=object),
#  array(['68130_3b'], dtype=object),
#  array(['68130_4b'], dtype=object),
#  array(['68130_8b'], dtype=object),
#  array(['68175_10b'], dtype=object),
#  array(['68175_1b'], dtype=object),
#  array(['68175_2b'], dtype=object),
#  array(['68175_3b'], dtype=object),
#  array(['68175_5b'], dtype=object),
#  array(['68175_6b'], dtype=object),
#  array(['68175_7b'], dtype=object),
#  array(['68175_8b'], dtype=object),
#  array(['68175_9b'], dtype=object),
#  array(['68676_1b'], dtype=object),
#  array(['68676_2b'], dtype=object),
#  array(['68676_3b'], dtype=object),
#  array(['68676_4b'], dtype=object),
#  array(['68676_5b'], dtype=object),
#  array(['68676_6b'], dtype=object),
#  array(['68676_8b'], dtype=object),
#  array(['69124_1917_b'], dtype=object),
#  array(['69124_1918_b'], dtype=object),
#  array(['69124_1b'], dtype=object),
#  array(['69124_2b'], dtype=object),
#  array(['69124_4b'], dtype=object),
#  array(['69124_5b'], dtype=object),
#  array(['69943_1b'], dtype=object),
#  array(['69943_3b'], dtype=object),
#  array(['69943_4b'], dtype=object),
#  array(['69943_6b'], dtype=object),
#  array(['69943_7b'], dtype=object),
#  array(['69943_8b'], dtype=object),
#  array(['69943_9b'], dtype=object),
#  array(['69974_1b'], dtype=object),
#  array(['69974_2b'], dtype=object),
#  array(['69974_4b'], dtype=object),
#  array(['69974_5b'], dtype=object),
#  array(['69974_6b'], dtype=object),
#  array(['69974_7b'], dtype=object),
#  array(['69974_8b'], dtype=object),
#  array(['69981_1b'], dtype=object),
#  array(['69981_2b'], dtype=object),
#  array(['69981_4b'], dtype=object),
#  array(['69981_5b'], dtype=object),
#  array(['69981_6b'], dtype=object),
#  array(['69981_7b'], dtype=object),
#  array(['69981_8b'], dtype=object),
#  array(['70261_10CG_b'], dtype=object),
#  array(['70261_10b'], dtype=object),
#  array(['70261_1b'], dtype=object),
#  array(['70261_3b'], dtype=object),
#  array(['70261_4b'], dtype=object),
#  array(['70261_5b'], dtype=object),
#  array(['70261_6b'], dtype=object),
#  array(['70261_7b'], dtype=object),
#  array(['70261_8b'], dtype=object),
#  array(['70261_9b'], dtype=object),
#  array(['70312_1b'], dtype=object),
#  array(['70312_2BISb'], dtype=object),
#  array(['70312_2b'], dtype=object),
#  array(['70312_3b'], dtype=object),
#  array(['70312_4b'], dtype=object),
#  array(['70312_5b'], dtype=object),
#  array(['70312_6b'], dtype=object),
#  array(['70312_7b'], dtype=object),
#  array(['70312_8b'], dtype=object),
#  array(['70312_9b'], dtype=object),
#  array(['70386_10b'], dtype=object),
#  array(['70386_1b'], dtype=object),
#  array(['70386_2b'], dtype=object),
#  array(['70386_3b'], dtype=object),
#  array(['70386_4b'], dtype=object),
#  array(['70386_5b'], dtype=object),
#  array(['70386_6b'], dtype=object),
#  array(['70386_8b'], dtype=object),
#  array(['70386_9b'], dtype=object),
#  array(['70575_1b'], dtype=object),
#  array(['70575_2b'], dtype=object),
#  array(['70575_3b'], dtype=object),
#  array(['70575_4b'], dtype=object),
#  array(['70575_5b'], dtype=object),
#  array(['70575_6b'], dtype=object),
#  array(['70575_7b'], dtype=object),
#  array(['70575_8b'], dtype=object),
#  array(['70636_10b'], dtype=object),
#  array(['70636_1b'], dtype=object),
#  array(['70636_2b'], dtype=object),
#  array(['70636_3b'], dtype=object),
#  array(['70636_4b'], dtype=object),
#  array(['70636_5b'], dtype=object),
#  array(['70636_7b'], dtype=object),
#  array(['70636_8b'], dtype=object),
#  array(['70636_9b'], dtype=object),
#  array(['71132_1917_b'], dtype=object),
#  array(['71132_1918_b'], dtype=object),
#  array(['71132_1b'], dtype=object),
#  array(['71132_2b'], dtype=object),
#  array(['71132_4b'], dtype=object),
#  array(['71132_5b'], dtype=object),
#  array(['71132_6b'], dtype=object),
#  array(['71132_7b'], dtype=object),
#  array(['71132_8b'], dtype=object),
#  array(['71133_1b'], dtype=object),
#  array(['71133_2b'], dtype=object),
#  array(['71133_3b'], dtype=object),
#  array(['71133_4b'], dtype=object),
#  array(['71133_5b'], dtype=object),
#  array(['71133_6b'], dtype=object),
#  array(['71133_7b'], dtype=object),
#  array(['71141_3b'], dtype=object),
#  array(['71141_4b'], dtype=object),
#  array(['71141_5b'], dtype=object),
#  array(['71141_6b'], dtype=object),
#  array(['71175_2b'], dtype=object),
#  array(['71175_3b'], dtype=object),
#  array(['71175_4b'], dtype=object),
#  array(['71175_5b'], dtype=object),
#  array(['71175_6b'], dtype=object),
#  array(['71175_7b'], dtype=object),
#  array(['71175_8b'], dtype=object),
#  array(['71175_9b'], dtype=object),
#  array(['71261_10b'], dtype=object),
#  array(['71261_11b'], dtype=object),
#  array(['71261_1b'], dtype=object),
#  array(['71261_2b'], dtype=object),
#  array(['71261_3b'], dtype=object),
#  array(['71261_4b'], dtype=object),
#  array(['71261_5b'], dtype=object),
#  array(['71261_6b'], dtype=object),
#  array(['71261_7b'], dtype=object),
#  array(['71261_8b'], dtype=object),
#  array(['71261_9b'], dtype=object),
#  array(['71288_10b'], dtype=object),
#  array(['71288_11b'], dtype=object),
#  array(['71288_1b'], dtype=object),
#  array(['71288_3b'], dtype=object),
#  array(['71288_4b'], dtype=object),
#  array(['71288_5b'], dtype=object),
#  array(['71288_6b'], dtype=object),
#  array(['71288_7b'], dtype=object),
#  array(['71288_8b'], dtype=object),
#  array(['71288_9b'], dtype=object),
#  array(['72056_1918_b'], dtype=object),
#  array(['72056_2b'], dtype=object),
#  array(['72056_3b'], dtype=object),
#  array(['72056_4b'], dtype=object),
#  array(['72056_5b'], dtype=object),
#  array(['72056_6b'], dtype=object),
#  array(['72056_7b'], dtype=object),
#  array(['72105_10b'], dtype=object),
#  array(['72105_11b'], dtype=object),
#  array(['72105_1b'], dtype=object),
#  array(['72105_2b'], dtype=object),
#  array(['72105_3b'], dtype=object),
#  array(['72105_4b'], dtype=object),
#  array(['72105_5b'], dtype=object),
#  array(['72105_6b'], dtype=object),
#  array(['72105_7b'], dtype=object),
#  array(['72105_8b'], dtype=object),
#  array(['72105_9b'], dtype=object),
#  array(['72212_10b'], dtype=object),
#  array(['72212_1b'], dtype=object),
#  array(['72212_2b'], dtype=object),
#  array(['72212_3b'], dtype=object),
#  array(['72212_4b'], dtype=object),
#  array(['72212_5b'], dtype=object),
#  array(['72212_7b'], dtype=object),
#  array(['72212_8b'], dtype=object),
#  array(['72212_9BISb'], dtype=object),
#  array(['72212_9b'], dtype=object),
#  array(['72263_10b'], dtype=object),
#  array(['72263_2b'], dtype=object),
#  array(['72263_3b'], dtype=object),
#  array(['72263_4b'], dtype=object),
#  array(['72263_5b'], dtype=object),
#  array(['72263_8CG_b'], dtype=object),
#  array(['72263_8b'], dtype=object),
#  array(['72263_9b'], dtype=object),
#  array(['73455_1b'], dtype=object),
#  array(['73455_2b'], dtype=object),
#  array(['73455_3b'], dtype=object),
#  array(['73455_5b'], dtype=object),
#  array(['73455_6b'], dtype=object),
#  array(['73500_1b'], dtype=object),
#  array(['73500_2b'], dtype=object),
#  array(['73500_3b'], dtype=object),
#  array(['73500_4b'], dtype=object),
#  array(['73500_5b'], dtype=object),
#  array(['73500_6b'], dtype=object),
#  array(['73500_7b'], dtype=object),
#  array(['73593_1b'], dtype=object),
#  array(['73593_2b'], dtype=object),
#  array(['73593_4b'], dtype=object),
#  array(['73593_5b'], dtype=object),
#  array(['73593_6b'], dtype=object),
#  array(['73593_8b'], dtype=object),
#  array(['73908_1b'], dtype=object),
#  array(['73908_2b'], dtype=object),
#  array(['73908_4b'], dtype=object),
#  array(['73908_6b'], dtype=object),
#  array(['73908_7b'], dtype=object),
#  array(['73908_8b'], dtype=object),
#  array(['73908_9b'], dtype=object),
#  array(['73971_2b'], dtype=object),
#  array(['73971_3b'], dtype=object),
#  array(['73971_4b'], dtype=object),
#  array(['76004_1b'], dtype=object),
#  array(['76004_2b'], dtype=object),
#  array(['76004_3b'], dtype=object),
#  array(['76004_4b'], dtype=object),
#  array(['76004_5b'], dtype=object),
#  array(['76004_6b'], dtype=object),
#  array(['76004_7b'], dtype=object),
#  array(['7797_2b'], dtype=object),
#  array(['7797_3b'], dtype=object),
#  array(['7797_4b'], dtype=object)]
