# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
import numpy as np

# %%
# Simple image to string
print(pytesseract.image_to_string(Image.open('test_samples/img9.PNG')))

# List of available languages
print(pytesseract.get_languages(config=''))

# French text image to string
print(pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra'))

# In order to bypass the image conversions of pytesseract, just use relative or absolute image path
# NOTE: In this case you should provide tesseract supported images or tesseract will return error
print(pytesseract.image_to_string('test.png'))

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['ita', 'osd', 'eng']

# %%
img = Image.open('test_samples/img9.PNG')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=447x634 at 0x7FF470D958D0>

# %%
img1 = Image.fromarray(np.array(img)[30:-50])
img1
# Out:
# <PIL.Image.Image image mode=RGBA size=447x554 at 0x7FF470D58FD0>

# %%
print(pytesseract.image_to_string(img1, lang='ita', nice=0))
# Out:
# CASSA NAZIONALE PER LE ASSICURAZIONI SOCIALI
#
# ASSICURAZIONI IGATORIE E
# per l'invalidità e la vecchiaia e per a disoccupazione involontaria
#
# ASSIURNTO N° _BZ) e MESSIN
#
# — tessenra N .
# (rote Gurattclo e rtuncia t ssaara | a E O a
# desta i rinneio Qusts data dava eunera apesta dul dutore)
#
# 2 auando appiieo l prima marta)
#
# “\ LI dltata 404
#
#
#
# J.MM {f
# ai A àuutﬂM) 1834
