# %%
import sys
sys.path.append('./faster_RCNN/')

from cell_dataset import CellDataset
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

import os
import shutil
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import cv2

from engine import train_one_epoch, evaluate
import utils
import transforms as T
import random

from sklearn.model_selection import train_test_split

# %%
def build_model(num_classes):
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model


def get_transform(train, augmentation_dict=None):
    transforms = []
    if train:
        for aug_key, factors in augmentation_dict.items():
            transforms.append(T.DataAugmentation(0.5, aug_key, factors[0], factors[1]))
        transforms.append(T.ToTensor())
#         transforms.append(T.RandomHorizontalFlip(0.5))
    else:
        transforms.append(T.ToTensor())
    return T.Compose(transforms)

# %%
ANN_PATH = "cellDetection_annotations.pkl"
IMG_DIR  = "../../download_from_drive/data/ProcessedO7"
AUGMENTATION_DICT = {
    'contrast': [0.5, 1.5],
    'brightness': [0.4, 1.5],
    'saturation': [0.4, 1.2],
    'gamma': [1, 1.25],
    'hue': [-0.1, 0.1]
}
BATCH_SIZE = 4
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

ann_df = pd.read_pickle('cellDetection_annotations.pkl')
ann_df["path"] = ann_df.filename.apply(lambda fn: os.path.join(IMG_DIR, fn.split("/")[-1].split(".json")[0]))
ann_df.drop(["filename", "value"], axis=1, inplace=True)

imgs = ann_df.path.unique()
train_imgs, valid_imgs = train_test_split(imgs, train_size=0.7, random_state=1234)

train_df = ann_df.query("path in @train_imgs")
valid_df = ann_df.query("path in @valid_imgs")

# %%
train_transforms = get_transform(train=True,  augmentation_dict=AUGMENTATION_DICT)
valid_transforms = get_transform(train=False, augmentation_dict=None)

train_ds = CellDataset(data_df=train_df, transforms=train_transforms)
valid_ds = CellDataset(data_df=valid_df, transforms=valid_transforms)

train_dl = torch.utils.data.DataLoader(
    dataset=train_ds,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=os.cpu_count(),
    collate_fn=utils.collate_fn
)

valid_dl = torch.utils.data.DataLoader(
    dataset=valid_ds,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=os.cpu_count(),
    collate_fn=utils.collate_fn
)

# %%
checkpoints_dir = 'trained_models'
if os.path.isdir(checkpoints_dir):
    shutil.rmtree(checkpoints_dir)
os.mkdir(checkpoints_dir)

# our dataset has two classes only - background and CELL
num_classes = 2
model = build_model(num_classes)
model.to(DEVICE)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# number of epochs
num_epochs = 30
for epoch in range(num_epochs):
    
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_dl, DEVICE, epoch, print_freq=10)
    
    # update the learning rate
    lr_scheduler.step()
    
    # evaluate on the test dataset
    evaluate(model, valid_dl, device=DEVICE)
    
    # save model afeter the current epoch
    torch.save(model, os.path.join(checkpoints_dir, 'checkpoint-' + str(epoch).zfill(2)) + '.pt')
    print()
    print()
# Out:
# Epoch: [0]  [ 0/36]  eta: 0:01:31  lr: 0.000148  loss: 6.0536 (6.0536)  loss_classifier: 0.6177 (0.6177)  loss_box_reg: 0.1642 (0.1642)  loss_objectness: 4.9627 (4.9627)  loss_rpn_box_reg: 0.3089 (0.3089)  time: 2.5430  data: 1.2861  max mem: 4442
# Epoch: [0]  [10/36]  eta: 0:00:32  lr: 0.001575  loss: 1.8091 (2.9530)  loss_classifier: 0.5734 (0.5661)  loss_box_reg: 0.6997 (0.5954)  loss_objectness: 0.3777 (1.6050)  loss_rpn_box_reg: 0.1788 (0.1865)  time: 1.2612  data: 0.1870  max mem: 4924
# Epoch: [0]  [20/36]  eta: 0:00:18  lr: 0.003002  loss: 1.5307 (2.1155)  loss_classifier: 0.4758 (0.4834)  loss_box_reg: 0.5587 (0.5752)  loss_objectness: 0.2768 (0.9261)  loss_rpn_box_reg: 0.0777 (0.1308)  time: 1.1018  data: 0.0526  max mem: 4924
# Epoch: [0]  [30/36]  eta: 0:00:06  lr: 0.004429  loss: 0.9257 (1.6843)  loss_classifier: 0.3025 (0.4156)  loss_box_reg: 0.4384 (0.5103)  loss_objectness: 0.1015 (0.6547)  loss_rpn_box_reg: 0.0549 (0.1037)  time: 1.0750  data: 0.0295  max mem: 4924
# Epoch: [0]  [35/36]  eta: 0:00:01  lr: 0.005000  loss: 0.7585 (1.5366)  loss_classifier: 0.2744 (0.3885)  loss_box_reg: 0.3765 (0.4836)  loss_objectness: 0.0814 (0.5709)  loss_rpn_box_reg: 0.0390 (0.0935)  time: 1.0715  data: 0.0289  max mem: 4924
# Epoch: [0] Total time: 0:00:40 (1.1315 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:37  model_time: 0.5263 (0.5263)  evaluator_time: 0.8863 (0.8863)  time: 2.3300  data: 0.8472  max mem: 4924
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4290 (0.4307)  evaluator_time: 0.3745 (0.3974)  time: 0.9553  data: 0.0806  max mem: 4924
# Test: Total time: 0:00:15 (0.9593 s / it)
# Averaged stats: model_time: 0.4290 (0.4307)  evaluator_time: 0.3745 (0.3974)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.691
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.174
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.753
#
#
# Epoch: [1]  [ 0/36]  eta: 0:01:28  lr: 0.005000  loss: 0.5067 (0.5067)  loss_classifier: 0.1852 (0.1852)  loss_box_reg: 0.2484 (0.2484)  loss_objectness: 0.0428 (0.0428)  loss_rpn_box_reg: 0.0303 (0.0303)  time: 2.4581  data: 1.3553  max mem: 4924
# Epoch: [1]  [10/36]  eta: 0:00:31  lr: 0.005000  loss: 0.5337 (0.5677)  loss_classifier: 0.2215 (0.2329)  loss_box_reg: 0.2288 (0.2389)  loss_objectness: 0.0564 (0.0644)  loss_rpn_box_reg: 0.0284 (0.0315)  time: 1.2033  data: 0.1497  max mem: 4924
# Epoch: [1]  [20/36]  eta: 0:00:18  lr: 0.005000  loss: 0.5121 (0.5342)  loss_classifier: 0.2018 (0.2160)  loss_box_reg: 0.2219 (0.2281)  loss_objectness: 0.0564 (0.0625)  loss_rpn_box_reg: 0.0225 (0.0276)  time: 1.0658  data: 0.0272  max mem: 4924
# Epoch: [1]  [30/36]  eta: 0:00:06  lr: 0.005000  loss: 0.3913 (0.4828)  loss_classifier: 0.1577 (0.1906)  loss_box_reg: 0.1780 (0.2117)  loss_objectness: 0.0399 (0.0556)  loss_rpn_box_reg: 0.0195 (0.0249)  time: 1.0655  data: 0.0299  max mem: 4931
# Epoch: [1]  [35/36]  eta: 0:00:01  lr: 0.005000  loss: 0.3744 (0.4684)  loss_classifier: 0.1423 (0.1842)  loss_box_reg: 0.1665 (0.2066)  loss_objectness: 0.0323 (0.0532)  loss_rpn_box_reg: 0.0190 (0.0244)  time: 1.0703  data: 0.0299  max mem: 4931
# Epoch: [1] Total time: 0:00:39 (1.1096 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:36  model_time: 0.5075 (0.5075)  evaluator_time: 0.8631 (0.8631)  time: 2.2533  data: 0.8157  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4309 (0.4297)  evaluator_time: 0.3555 (0.3796)  time: 0.9415  data: 0.0860  max mem: 4931
# Test: Total time: 0:00:15 (0.9454 s / it)
# Averaged stats: model_time: 0.4309 (0.4297)  evaluator_time: 0.3555 (0.3796)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.759
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.414
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.833
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.683
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
#
#
# Epoch: [2]  [ 0/36]  eta: 0:01:50  lr: 0.005000  loss: 0.3193 (0.3193)  loss_classifier: 0.1212 (0.1212)  loss_box_reg: 0.1470 (0.1470)  loss_objectness: 0.0372 (0.0372)  loss_rpn_box_reg: 0.0138 (0.0138)  time: 3.0749  data: 1.9487  max mem: 4931
# Epoch: [2]  [10/36]  eta: 0:00:32  lr: 0.005000  loss: 0.2765 (0.2823)  loss_classifier: 0.1012 (0.1039)  loss_box_reg: 0.1326 (0.1376)  loss_objectness: 0.0219 (0.0240)  loss_rpn_box_reg: 0.0138 (0.0168)  time: 1.2461  data: 0.2005  max mem: 4931
# Epoch: [2]  [20/36]  eta: 0:00:18  lr: 0.005000  loss: 0.2586 (0.2754)  loss_classifier: 0.0905 (0.0989)  loss_box_reg: 0.1326 (0.1381)  loss_objectness: 0.0189 (0.0227)  loss_rpn_box_reg: 0.0123 (0.0157)  time: 1.0728  data: 0.0282  max mem: 4931
# Epoch: [2]  [30/36]  eta: 0:00:06  lr: 0.005000  loss: 0.2626 (0.2838)  loss_classifier: 0.0913 (0.1044)  loss_box_reg: 0.1492 (0.1437)  loss_objectness: 0.0139 (0.0204)  loss_rpn_box_reg: 0.0123 (0.0152)  time: 1.0748  data: 0.0307  max mem: 4931
# Epoch: [2]  [35/36]  eta: 0:00:01  lr: 0.005000  loss: 0.2586 (0.2803)  loss_classifier: 0.0968 (0.1063)  loss_box_reg: 0.1351 (0.1405)  loss_objectness: 0.0124 (0.0189)  loss_rpn_box_reg: 0.0123 (0.0146)  time: 1.0686  data: 0.0281  max mem: 4931
# Epoch: [2] Total time: 0:00:40 (1.1266 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:36  model_time: 0.5310 (0.5310)  evaluator_time: 0.8260 (0.8260)  time: 2.2823  data: 0.8511  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4312 (0.4324)  evaluator_time: 0.3120 (0.3357)  time: 0.9013  data: 0.0873  max mem: 4931
# Test: Total time: 0:00:14 (0.9052 s / it)
# Averaged stats: model_time: 0.4312 (0.4324)  evaluator_time: 0.3120 (0.3357)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.976
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.962
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.583
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.777
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
#
#
# Epoch: [3]  [ 0/36]  eta: 0:01:29  lr: 0.000500  loss: 0.2240 (0.2240)  loss_classifier: 0.0762 (0.0762)  loss_box_reg: 0.1305 (0.1305)  loss_objectness: 0.0084 (0.0084)  loss_rpn_box_reg: 0.0089 (0.0089)  time: 2.4941  data: 1.2819  max mem: 4931
# Epoch: [3]  [10/36]  eta: 0:00:31  lr: 0.000500  loss: 0.2240 (0.2491)  loss_classifier: 0.0917 (0.1001)  loss_box_reg: 0.1108 (0.1277)  loss_objectness: 0.0088 (0.0101)  loss_rpn_box_reg: 0.0098 (0.0113)  time: 1.2154  data: 0.1482  max mem: 4931
# Epoch: [3]  [20/36]  eta: 0:00:18  lr: 0.000500  loss: 0.2075 (0.2335)  loss_classifier: 0.0826 (0.0947)  loss_box_reg: 0.1087 (0.1193)  loss_objectness: 0.0088 (0.0092)  loss_rpn_box_reg: 0.0087 (0.0103)  time: 1.0822  data: 0.0320  max mem: 4931
# Epoch: [3]  [30/36]  eta: 0:00:06  lr: 0.000500  loss: 0.1925 (0.2276)  loss_classifier: 0.0799 (0.0927)  loss_box_reg: 0.0967 (0.1154)  loss_objectness: 0.0071 (0.0098)  loss_rpn_box_reg: 0.0074 (0.0098)  time: 1.0764  data: 0.0296  max mem: 4931
# Epoch: [3]  [35/36]  eta: 0:00:01  lr: 0.000500  loss: 0.1884 (0.2251)  loss_classifier: 0.0799 (0.0921)  loss_box_reg: 0.0924 (0.1141)  loss_objectness: 0.0070 (0.0093)  loss_rpn_box_reg: 0.0067 (0.0096)  time: 1.0742  data: 0.0283  max mem: 4931
# Epoch: [3] Total time: 0:00:40 (1.1203 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:31  model_time: 0.5231 (0.5231)  evaluator_time: 0.5390 (0.5390)  time: 1.9895  data: 0.8525  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4349 (0.4352)  evaluator_time: 0.2244 (0.2408)  time: 0.8330  data: 0.1099  max mem: 4931
# Test: Total time: 0:00:13 (0.8369 s / it)
# Averaged stats: model_time: 0.4349 (0.4352)  evaluator_time: 0.2244 (0.2408)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.848
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.657
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.896
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.897
#
#
# Epoch: [4]  [ 0/36]  eta: 0:02:48  lr: 0.000500  loss: 0.2035 (0.2035)  loss_classifier: 0.0858 (0.0858)  loss_box_reg: 0.1001 (0.1001)  loss_objectness: 0.0085 (0.0085)  loss_rpn_box_reg: 0.0091 (0.0091)  time: 4.6820  data: 3.5660  max mem: 4931
# Epoch: [4]  [10/36]  eta: 0:00:36  lr: 0.000500  loss: 0.1972 (0.2194)  loss_classifier: 0.0786 (0.0917)  loss_box_reg: 0.0976 (0.1087)  loss_objectness: 0.0085 (0.0103)  loss_rpn_box_reg: 0.0077 (0.0088)  time: 1.4065  data: 0.3471  max mem: 4931
# Epoch: [4]  [20/36]  eta: 0:00:20  lr: 0.000500  loss: 0.1972 (0.2147)  loss_classifier: 0.0786 (0.0924)  loss_box_reg: 0.0971 (0.1051)  loss_objectness: 0.0067 (0.0084)  loss_rpn_box_reg: 0.0077 (0.0087)  time: 1.0809  data: 0.0253  max mem: 4931
# Epoch: [4]  [30/36]  eta: 0:00:07  lr: 0.000500  loss: 0.1907 (0.2113)  loss_classifier: 0.0741 (0.0882)  loss_box_reg: 0.0969 (0.1056)  loss_objectness: 0.0067 (0.0090)  loss_rpn_box_reg: 0.0080 (0.0085)  time: 1.0992  data: 0.0347  max mem: 4931
# Epoch: [4]  [35/36]  eta: 0:00:01  lr: 0.000500  loss: 0.1693 (0.2053)  loss_classifier: 0.0689 (0.0858)  loss_box_reg: 0.0906 (0.1025)  loss_objectness: 0.0067 (0.0086)  loss_rpn_box_reg: 0.0068 (0.0083)  time: 1.0980  data: 0.0331  max mem: 4931
# Epoch: [4] Total time: 0:00:42 (1.1934 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:31  model_time: 0.5350 (0.5350)  evaluator_time: 0.5724 (0.5724)  time: 1.9509  data: 0.7722  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4447 (0.4452)  evaluator_time: 0.2351 (0.2545)  time: 0.8479  data: 0.1019  max mem: 4931
# Test: Total time: 0:00:13 (0.8522 s / it)
# Averaged stats: model_time: 0.4447 (0.4452)  evaluator_time: 0.2351 (0.2545)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.854
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.968
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.642
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [5]  [ 0/36]  eta: 0:01:52  lr: 0.000500  loss: 0.1307 (0.1307)  loss_classifier: 0.0520 (0.0520)  loss_box_reg: 0.0699 (0.0699)  loss_objectness: 0.0039 (0.0039)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 3.1364  data: 1.9518  max mem: 4931
# Epoch: [5]  [10/36]  eta: 0:00:34  lr: 0.000500  loss: 0.1798 (0.2090)  loss_classifier: 0.0737 (0.0890)  loss_box_reg: 0.0932 (0.1005)  loss_objectness: 0.0059 (0.0105)  loss_rpn_box_reg: 0.0081 (0.0089)  time: 1.3253  data: 0.2199  max mem: 4931
# Epoch: [5]  [20/36]  eta: 0:00:19  lr: 0.000500  loss: 0.1797 (0.2153)  loss_classifier: 0.0735 (0.0887)  loss_box_reg: 0.0940 (0.1083)  loss_objectness: 0.0050 (0.0095)  loss_rpn_box_reg: 0.0076 (0.0088)  time: 1.1269  data: 0.0372  max mem: 4931
# Epoch: [5]  [30/36]  eta: 0:00:07  lr: 0.000500  loss: 0.1703 (0.2099)  loss_classifier: 0.0657 (0.0855)  loss_box_reg: 0.0963 (0.1073)  loss_objectness: 0.0040 (0.0086)  loss_rpn_box_reg: 0.0067 (0.0086)  time: 1.1157  data: 0.0279  max mem: 4931
# Epoch: [5]  [35/36]  eta: 0:00:01  lr: 0.000500  loss: 0.1710 (0.2137)  loss_classifier: 0.0685 (0.0864)  loss_box_reg: 0.0963 (0.1073)  loss_objectness: 0.0043 (0.0111)  loss_rpn_box_reg: 0.0079 (0.0089)  time: 1.1256  data: 0.0283  max mem: 4931
# Epoch: [5] Total time: 0:00:42 (1.1851 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5576 (0.5576)  evaluator_time: 0.6302 (0.6302)  time: 2.0868  data: 0.8309  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4517 (0.4539)  evaluator_time: 0.2220 (0.2417)  time: 0.8407  data: 0.0983  max mem: 4931
# Test: Total time: 0:00:13 (0.8448 s / it)
# Averaged stats: model_time: 0.4517 (0.4539)  evaluator_time: 0.2220 (0.2417)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.856
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.645
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.858
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.903
#
#
# Epoch: [6]  [ 0/36]  eta: 0:01:42  lr: 0.000050  loss: 0.2753 (0.2753)  loss_classifier: 0.1261 (0.1261)  loss_box_reg: 0.1268 (0.1268)  loss_objectness: 0.0103 (0.0103)  loss_rpn_box_reg: 0.0121 (0.0121)  time: 2.8541  data: 1.6740  max mem: 4931
# Epoch: [6]  [10/36]  eta: 0:00:33  lr: 0.000050  loss: 0.1745 (0.2298)  loss_classifier: 0.0791 (0.0992)  loss_box_reg: 0.0870 (0.1088)  loss_objectness: 0.0053 (0.0124)  loss_rpn_box_reg: 0.0074 (0.0094)  time: 1.2875  data: 0.1760  max mem: 4931
# Epoch: [6]  [20/36]  eta: 0:00:19  lr: 0.000050  loss: 0.1693 (0.2034)  loss_classifier: 0.0694 (0.0851)  loss_box_reg: 0.0897 (0.1010)  loss_objectness: 0.0053 (0.0091)  loss_rpn_box_reg: 0.0062 (0.0082)  time: 1.1350  data: 0.0253  max mem: 4931
# Epoch: [6]  [30/36]  eta: 0:00:07  lr: 0.000050  loss: 0.1779 (0.1983)  loss_classifier: 0.0699 (0.0826)  loss_box_reg: 0.0898 (0.0994)  loss_objectness: 0.0047 (0.0082)  loss_rpn_box_reg: 0.0067 (0.0081)  time: 1.1524  data: 0.0273  max mem: 4931
# Epoch: [6]  [35/36]  eta: 0:00:01  lr: 0.000050  loss: 0.1779 (0.1947)  loss_classifier: 0.0699 (0.0802)  loss_box_reg: 0.0897 (0.0988)  loss_objectness: 0.0047 (0.0077)  loss_rpn_box_reg: 0.0067 (0.0079)  time: 1.1595  data: 0.0284  max mem: 4931
# Epoch: [6] Total time: 0:00:43 (1.1971 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:31  model_time: 0.5167 (0.5167)  evaluator_time: 0.5878 (0.5878)  time: 1.9838  data: 0.8365  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4632 (0.4610)  evaluator_time: 0.2158 (0.2338)  time: 0.8456  data: 0.1055  max mem: 4931
# Test: Total time: 0:00:13 (0.8497 s / it)
# Averaged stats: model_time: 0.4632 (0.4610)  evaluator_time: 0.2158 (0.2338)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.856
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.644
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [7]  [ 0/36]  eta: 0:02:07  lr: 0.000050  loss: 0.1607 (0.1607)  loss_classifier: 0.0611 (0.0611)  loss_box_reg: 0.0824 (0.0824)  loss_objectness: 0.0102 (0.0102)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 3.5394  data: 2.3309  max mem: 4931
# Epoch: [7]  [10/36]  eta: 0:00:35  lr: 0.000050  loss: 0.1885 (0.2070)  loss_classifier: 0.0816 (0.0880)  loss_box_reg: 0.0969 (0.1035)  loss_objectness: 0.0056 (0.0076)  loss_rpn_box_reg: 0.0070 (0.0079)  time: 1.3714  data: 0.2345  max mem: 4931
# Epoch: [7]  [20/36]  eta: 0:00:20  lr: 0.000050  loss: 0.1786 (0.1922)  loss_classifier: 0.0686 (0.0794)  loss_box_reg: 0.0969 (0.0982)  loss_objectness: 0.0056 (0.0071)  loss_rpn_box_reg: 0.0064 (0.0075)  time: 1.1564  data: 0.0257  max mem: 4931
# Epoch: [7]  [30/36]  eta: 0:00:07  lr: 0.000050  loss: 0.1712 (0.1870)  loss_classifier: 0.0676 (0.0773)  loss_box_reg: 0.0902 (0.0957)  loss_objectness: 0.0055 (0.0064)  loss_rpn_box_reg: 0.0070 (0.0075)  time: 1.1646  data: 0.0280  max mem: 4931
# Epoch: [7]  [35/36]  eta: 0:00:01  lr: 0.000050  loss: 0.1712 (0.1857)  loss_classifier: 0.0644 (0.0772)  loss_box_reg: 0.0890 (0.0949)  loss_objectness: 0.0046 (0.0061)  loss_rpn_box_reg: 0.0070 (0.0076)  time: 1.1669  data: 0.0277  max mem: 4931
# Epoch: [7] Total time: 0:00:44 (1.2307 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5502 (0.5502)  evaluator_time: 0.6453 (0.6453)  time: 2.1013  data: 0.8240  max mem: 4931
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4674 (0.4675)  evaluator_time: 0.2185 (0.2407)  time: 0.8601  data: 0.1050  max mem: 5143
# Test: Total time: 0:00:13 (0.8644 s / it)
# Averaged stats: model_time: 0.4674 (0.4675)  evaluator_time: 0.2185 (0.2407)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [20]  [ 0/36]  eta: 0:02:17  lr: 0.000000  loss: 0.1626 (0.1626)  loss_classifier: 0.0756 (0.0756)  loss_box_reg: 0.0768 (0.0768)  loss_objectness: 0.0034 (0.0034)  loss_rpn_box_reg: 0.0068 (0.0068)  time: 3.8140  data: 2.6150  max mem: 5143
# Epoch: [20]  [10/36]  eta: 0:00:36  lr: 0.000000  loss: 0.1626 (0.1996)  loss_classifier: 0.0616 (0.0751)  loss_box_reg: 0.0903 (0.1005)  loss_objectness: 0.0047 (0.0157)  loss_rpn_box_reg: 0.0068 (0.0083)  time: 1.4089  data: 0.2614  max mem: 5143
# Epoch: [20]  [20/36]  eta: 0:00:20  lr: 0.000000  loss: 0.1713 (0.1849)  loss_classifier: 0.0616 (0.0724)  loss_box_reg: 0.0888 (0.0939)  loss_objectness: 0.0049 (0.0112)  loss_rpn_box_reg: 0.0062 (0.0074)  time: 1.1795  data: 0.0284  max mem: 5143
# Epoch: [20]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1713 (0.1877)  loss_classifier: 0.0645 (0.0740)  loss_box_reg: 0.0897 (0.0962)  loss_objectness: 0.0054 (0.0099)  loss_rpn_box_reg: 0.0065 (0.0076)  time: 1.1902  data: 0.0291  max mem: 5143
# Epoch: [20]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1748 (0.1907)  loss_classifier: 0.0691 (0.0766)  loss_box_reg: 0.0931 (0.0968)  loss_objectness: 0.0049 (0.0093)  loss_rpn_box_reg: 0.0074 (0.0079)  time: 1.1888  data: 0.0288  max mem: 5143
# Epoch: [20] Total time: 0:00:45 (1.2574 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:35  model_time: 0.5958 (0.5958)  evaluator_time: 0.6909 (0.6909)  time: 2.2125  data: 0.8550  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4634 (0.4663)  evaluator_time: 0.2179 (0.2435)  time: 0.8470  data: 0.0910  max mem: 5143
# Test: Total time: 0:00:13 (0.8508 s / it)
# Averaged stats: model_time: 0.4634 (0.4663)  evaluator_time: 0.2179 (0.2435)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [21]  [ 0/36]  eta: 0:02:51  lr: 0.000000  loss: 0.1872 (0.1872)  loss_classifier: 0.0737 (0.0737)  loss_box_reg: 0.0987 (0.0987)  loss_objectness: 0.0055 (0.0055)  loss_rpn_box_reg: 0.0093 (0.0093)  time: 4.7726  data: 3.5880  max mem: 5143
# Epoch: [21]  [10/36]  eta: 0:00:39  lr: 0.000000  loss: 0.1725 (0.1842)  loss_classifier: 0.0737 (0.0789)  loss_box_reg: 0.0862 (0.0922)  loss_objectness: 0.0048 (0.0053)  loss_rpn_box_reg: 0.0071 (0.0080)  time: 1.5021  data: 0.3713  max mem: 5143
# Epoch: [21]  [20/36]  eta: 0:00:21  lr: 0.000000  loss: 0.1645 (0.1831)  loss_classifier: 0.0632 (0.0748)  loss_box_reg: 0.0884 (0.0947)  loss_objectness: 0.0048 (0.0058)  loss_rpn_box_reg: 0.0068 (0.0078)  time: 1.1743  data: 0.0403  max mem: 5143
# Epoch: [21]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1644 (0.1875)  loss_classifier: 0.0627 (0.0783)  loss_box_reg: 0.0884 (0.0951)  loss_objectness: 0.0052 (0.0065)  loss_rpn_box_reg: 0.0071 (0.0076)  time: 1.1725  data: 0.0278  max mem: 5143
# Epoch: [21]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1574 (0.1941)  loss_classifier: 0.0627 (0.0814)  loss_box_reg: 0.0874 (0.0977)  loss_objectness: 0.0053 (0.0072)  loss_rpn_box_reg: 0.0071 (0.0078)  time: 1.1719  data: 0.0259  max mem: 5143
# Epoch: [21] Total time: 0:00:45 (1.2742 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5363 (0.5363)  evaluator_time: 0.6433 (0.6433)  time: 2.0680  data: 0.7947  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4695 (0.4681)  evaluator_time: 0.2191 (0.2442)  time: 0.8560  data: 0.0953  max mem: 5143
# Test: Total time: 0:00:13 (0.8602 s / it)
# Averaged stats: model_time: 0.4695 (0.4681)  evaluator_time: 0.2191 (0.2442)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [22]  [ 0/36]  eta: 0:02:47  lr: 0.000000  loss: 0.1651 (0.1651)  loss_classifier: 0.0673 (0.0673)  loss_box_reg: 0.0844 (0.0844)  loss_objectness: 0.0047 (0.0047)  loss_rpn_box_reg: 0.0087 (0.0087)  time: 4.6634  data: 3.4472  max mem: 5143
# Epoch: [22]  [10/36]  eta: 0:00:38  lr: 0.000000  loss: 0.1694 (0.2022)  loss_classifier: 0.0714 (0.0864)  loss_box_reg: 0.0965 (0.1004)  loss_objectness: 0.0061 (0.0073)  loss_rpn_box_reg: 0.0071 (0.0081)  time: 1.4784  data: 0.3327  max mem: 5143
# Epoch: [22]  [20/36]  eta: 0:00:21  lr: 0.000000  loss: 0.1763 (0.1995)  loss_classifier: 0.0731 (0.0842)  loss_box_reg: 0.0965 (0.0995)  loss_objectness: 0.0066 (0.0078)  loss_rpn_box_reg: 0.0066 (0.0080)  time: 1.1697  data: 0.0232  max mem: 5143
# Epoch: [22]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1722 (0.2115)  loss_classifier: 0.0679 (0.0869)  loss_box_reg: 0.0966 (0.1062)  loss_objectness: 0.0065 (0.0100)  loss_rpn_box_reg: 0.0068 (0.0085)  time: 1.1813  data: 0.0257  max mem: 5143
# Epoch: [22]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1722 (0.2098)  loss_classifier: 0.0664 (0.0862)  loss_box_reg: 0.0966 (0.1054)  loss_objectness: 0.0066 (0.0097)  loss_rpn_box_reg: 0.0068 (0.0085)  time: 1.1884  data: 0.0273  max mem: 5143
# Epoch: [22] Total time: 0:00:45 (1.2771 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5443 (0.5443)  evaluator_time: 0.6660 (0.6660)  time: 2.0744  data: 0.7884  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4682 (0.4671)  evaluator_time: 0.2198 (0.2421)  time: 0.8572  data: 0.1006  max mem: 5143
# Test: Total time: 0:00:13 (0.8613 s / it)
# Averaged stats: model_time: 0.4682 (0.4671)  evaluator_time: 0.2198 (0.2421)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [23]  [ 0/36]  eta: 0:01:38  lr: 0.000000  loss: 0.1700 (0.1700)  loss_classifier: 0.0712 (0.0712)  loss_box_reg: 0.0860 (0.0860)  loss_objectness: 0.0059 (0.0059)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 2.7369  data: 1.5179  max mem: 5143
# Epoch: [23]  [10/36]  eta: 0:00:36  lr: 0.000000  loss: 0.1763 (0.1892)  loss_classifier: 0.0712 (0.0802)  loss_box_reg: 0.0869 (0.0949)  loss_objectness: 0.0059 (0.0059)  loss_rpn_box_reg: 0.0082 (0.0081)  time: 1.4005  data: 0.2476  max mem: 5143
# Epoch: [23]  [20/36]  eta: 0:00:20  lr: 0.000000  loss: 0.1763 (0.1908)  loss_classifier: 0.0671 (0.0803)  loss_box_reg: 0.0876 (0.0971)  loss_objectness: 0.0043 (0.0053)  loss_rpn_box_reg: 0.0080 (0.0081)  time: 1.2271  data: 0.0748  max mem: 5143
# Epoch: [23]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1671 (0.1894)  loss_classifier: 0.0671 (0.0788)  loss_box_reg: 0.0881 (0.0975)  loss_objectness: 0.0036 (0.0051)  loss_rpn_box_reg: 0.0068 (0.0079)  time: 1.1873  data: 0.0286  max mem: 5143
# Epoch: [23]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1671 (0.1861)  loss_classifier: 0.0663 (0.0769)  loss_box_reg: 0.0888 (0.0964)  loss_objectness: 0.0036 (0.0050)  loss_rpn_box_reg: 0.0069 (0.0078)  time: 1.1873  data: 0.0285  max mem: 5143
# Epoch: [23] Total time: 0:00:45 (1.2534 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5625 (0.5625)  evaluator_time: 0.6760 (0.6760)  time: 2.1176  data: 0.8021  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4616 (0.4630)  evaluator_time: 0.2216 (0.2430)  time: 0.8422  data: 0.0889  max mem: 5143
# Test: Total time: 0:00:13 (0.8462 s / it)
# Averaged stats: model_time: 0.4616 (0.4630)  evaluator_time: 0.2216 (0.2430)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [24]  [ 0/36]  eta: 0:01:22  lr: 0.000000  loss: 0.1449 (0.1449)  loss_classifier: 0.0634 (0.0634)  loss_box_reg: 0.0716 (0.0716)  loss_objectness: 0.0050 (0.0050)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 2.3022  data: 1.1383  max mem: 5143
# Epoch: [24]  [10/36]  eta: 0:00:33  lr: 0.000000  loss: 0.1988 (0.2180)  loss_classifier: 0.0715 (0.0909)  loss_box_reg: 0.1003 (0.1073)  loss_objectness: 0.0069 (0.0110)  loss_rpn_box_reg: 0.0084 (0.0088)  time: 1.2736  data: 0.1449  max mem: 5143
# Epoch: [24]  [20/36]  eta: 0:00:19  lr: 0.000000  loss: 0.1816 (0.1952)  loss_classifier: 0.0681 (0.0796)  loss_box_reg: 0.0966 (0.0995)  loss_objectness: 0.0047 (0.0079)  loss_rpn_box_reg: 0.0076 (0.0082)  time: 1.1734  data: 0.0398  max mem: 5143
# Epoch: [24]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1787 (0.1950)  loss_classifier: 0.0681 (0.0806)  loss_box_reg: 0.0865 (0.0987)  loss_objectness: 0.0043 (0.0077)  loss_rpn_box_reg: 0.0076 (0.0080)  time: 1.1789  data: 0.0308  max mem: 5143
# Epoch: [24]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1787 (0.1903)  loss_classifier: 0.0694 (0.0785)  loss_box_reg: 0.0793 (0.0965)  loss_objectness: 0.0041 (0.0075)  loss_rpn_box_reg: 0.0060 (0.0077)  time: 1.1773  data: 0.0283  max mem: 5143
# Epoch: [24] Total time: 0:00:43 (1.2079 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:32  model_time: 0.5508 (0.5508)  evaluator_time: 0.5413 (0.5413)  time: 2.0020  data: 0.8259  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4701 (0.4694)  evaluator_time: 0.2195 (0.2333)  time: 0.8605  data: 0.1110  max mem: 5143
# Test: Total time: 0:00:13 (0.8647 s / it)
# Averaged stats: model_time: 0.4701 (0.4694)  evaluator_time: 0.2195 (0.2333)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [25]  [ 0/36]  eta: 0:01:21  lr: 0.000000  loss: 0.1547 (0.1547)  loss_classifier: 0.0604 (0.0604)  loss_box_reg: 0.0858 (0.0858)  loss_objectness: 0.0026 (0.0026)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 2.2707  data: 1.0960  max mem: 5143
# Epoch: [25]  [10/36]  eta: 0:00:33  lr: 0.000000  loss: 0.1773 (0.2169)  loss_classifier: 0.0725 (0.0900)  loss_box_reg: 0.0858 (0.1047)  loss_objectness: 0.0079 (0.0134)  loss_rpn_box_reg: 0.0072 (0.0088)  time: 1.3068  data: 0.1444  max mem: 5143
# Epoch: [25]  [20/36]  eta: 0:00:19  lr: 0.000000  loss: 0.1803 (0.2121)  loss_classifier: 0.0792 (0.0899)  loss_box_reg: 0.0851 (0.1028)  loss_objectness: 0.0067 (0.0108)  loss_rpn_box_reg: 0.0070 (0.0086)  time: 1.1966  data: 0.0386  max mem: 5143
# Epoch: [25]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1829 (0.2185)  loss_classifier: 0.0791 (0.0896)  loss_box_reg: 0.0872 (0.1096)  loss_objectness: 0.0056 (0.0105)  loss_rpn_box_reg: 0.0082 (0.0088)  time: 1.1862  data: 0.0278  max mem: 5143
# Epoch: [25]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1803 (0.2116)  loss_classifier: 0.0715 (0.0868)  loss_box_reg: 0.0887 (0.1065)  loss_objectness: 0.0056 (0.0099)  loss_rpn_box_reg: 0.0082 (0.0085)  time: 1.1868  data: 0.0267  max mem: 5143
# Epoch: [25] Total time: 0:00:44 (1.2256 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:35  model_time: 0.5995 (0.5995)  evaluator_time: 0.6753 (0.6753)  time: 2.2008  data: 0.8431  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4644 (0.4675)  evaluator_time: 0.2199 (0.2425)  time: 0.8547  data: 0.0982  max mem: 5143
# Test: Total time: 0:00:13 (0.8588 s / it)
# Averaged stats: model_time: 0.4644 (0.4675)  evaluator_time: 0.2199 (0.2425)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [26]  [ 0/36]  eta: 0:01:54  lr: 0.000000  loss: 0.1376 (0.1376)  loss_classifier: 0.0662 (0.0662)  loss_box_reg: 0.0632 (0.0632)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 3.1941  data: 1.9201  max mem: 5143
# Epoch: [26]  [10/36]  eta: 0:00:35  lr: 0.000000  loss: 0.1601 (0.1739)  loss_classifier: 0.0655 (0.0733)  loss_box_reg: 0.0839 (0.0888)  loss_objectness: 0.0035 (0.0050)  loss_rpn_box_reg: 0.0061 (0.0068)  time: 1.3654  data: 0.2146  max mem: 5143
# Epoch: [26]  [20/36]  eta: 0:00:20  lr: 0.000000  loss: 0.1703 (0.2266)  loss_classifier: 0.0669 (0.0941)  loss_box_reg: 0.0942 (0.1111)  loss_objectness: 0.0045 (0.0126)  loss_rpn_box_reg: 0.0070 (0.0089)  time: 1.1761  data: 0.0356  max mem: 5143
# Epoch: [26]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.2163 (0.2202)  loss_classifier: 0.0819 (0.0929)  loss_box_reg: 0.0965 (0.1079)  loss_objectness: 0.0063 (0.0108)  loss_rpn_box_reg: 0.0078 (0.0086)  time: 1.1697  data: 0.0264  max mem: 5143
# Epoch: [26]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1936 (0.2272)  loss_classifier: 0.0786 (0.0942)  loss_box_reg: 0.0965 (0.1097)  loss_objectness: 0.0063 (0.0141)  loss_rpn_box_reg: 0.0087 (0.0091)  time: 1.1761  data: 0.0269  max mem: 5143
# Epoch: [26] Total time: 0:00:44 (1.2347 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5326 (0.5326)  evaluator_time: 0.6572 (0.6572)  time: 2.0821  data: 0.8261  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4693 (0.4683)  evaluator_time: 0.2202 (0.2411)  time: 0.8445  data: 0.0894  max mem: 5143
# Test: Total time: 0:00:13 (0.8485 s / it)
# Averaged stats: model_time: 0.4693 (0.4683)  evaluator_time: 0.2202 (0.2411)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [27]  [ 0/36]  eta: 0:01:25  lr: 0.000000  loss: 0.1840 (0.1840)  loss_classifier: 0.0703 (0.0703)  loss_box_reg: 0.1053 (0.1053)  loss_objectness: 0.0014 (0.0014)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 2.3852  data: 1.1627  max mem: 5143
# Epoch: [27]  [10/36]  eta: 0:00:34  lr: 0.000000  loss: 0.1636 (0.1627)  loss_classifier: 0.0677 (0.0679)  loss_box_reg: 0.0826 (0.0837)  loss_objectness: 0.0039 (0.0045)  loss_rpn_box_reg: 0.0067 (0.0066)  time: 1.3273  data: 0.1561  max mem: 5143
# Epoch: [27]  [20/36]  eta: 0:00:20  lr: 0.000000  loss: 0.1646 (0.1908)  loss_classifier: 0.0677 (0.0796)  loss_box_reg: 0.0854 (0.0953)  loss_objectness: 0.0045 (0.0079)  loss_rpn_box_reg: 0.0067 (0.0080)  time: 1.2070  data: 0.0441  max mem: 5143
# Epoch: [27]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1653 (0.1955)  loss_classifier: 0.0688 (0.0813)  loss_box_reg: 0.0929 (0.0975)  loss_objectness: 0.0046 (0.0086)  loss_rpn_box_reg: 0.0067 (0.0081)  time: 1.1846  data: 0.0291  max mem: 5143
# Epoch: [27]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1646 (0.1935)  loss_classifier: 0.0707 (0.0805)  loss_box_reg: 0.0915 (0.0969)  loss_objectness: 0.0045 (0.0080)  loss_rpn_box_reg: 0.0067 (0.0081)  time: 1.1811  data: 0.0268  max mem: 5143
# Epoch: [27] Total time: 0:00:44 (1.2300 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:32  model_time: 0.5479 (0.5479)  evaluator_time: 0.6250 (0.6250)  time: 2.0506  data: 0.8310  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4640 (0.4639)  evaluator_time: 0.2204 (0.2393)  time: 0.8566  data: 0.1074  max mem: 5143
# Test: Total time: 0:00:13 (0.8607 s / it)
# Averaged stats: model_time: 0.4640 (0.4639)  evaluator_time: 0.2204 (0.2393)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [28]  [ 0/36]  eta: 0:01:34  lr: 0.000000  loss: 0.1178 (0.1178)  loss_classifier: 0.0524 (0.0524)  loss_box_reg: 0.0585 (0.0585)  loss_objectness: 0.0020 (0.0020)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 2.6292  data: 1.4305  max mem: 5143
# Epoch: [28]  [10/36]  eta: 0:00:35  lr: 0.000000  loss: 0.1669 (0.2091)  loss_classifier: 0.0626 (0.0859)  loss_box_reg: 0.0905 (0.1053)  loss_objectness: 0.0056 (0.0093)  loss_rpn_box_reg: 0.0080 (0.0087)  time: 1.3749  data: 0.2244  max mem: 5143
# Epoch: [28]  [20/36]  eta: 0:00:20  lr: 0.000000  loss: 0.1701 (0.2115)  loss_classifier: 0.0716 (0.0895)  loss_box_reg: 0.0902 (0.1043)  loss_objectness: 0.0068 (0.0090)  loss_rpn_box_reg: 0.0075 (0.0087)  time: 1.2072  data: 0.0637  max mem: 5143
# Epoch: [28]  [30/36]  eta: 0:00:07  lr: 0.000000  loss: 0.1544 (0.1950)  loss_classifier: 0.0697 (0.0817)  loss_box_reg: 0.0839 (0.0980)  loss_objectness: 0.0036 (0.0075)  loss_rpn_box_reg: 0.0059 (0.0078)  time: 1.1704  data: 0.0231  max mem: 5143
# Epoch: [28]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1522 (0.1959)  loss_classifier: 0.0589 (0.0812)  loss_box_reg: 0.0839 (0.0992)  loss_objectness: 0.0031 (0.0074)  loss_rpn_box_reg: 0.0059 (0.0081)  time: 1.1814  data: 0.0264  max mem: 5143
# Epoch: [28] Total time: 0:00:44 (1.2388 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:34  model_time: 0.5394 (0.5394)  evaluator_time: 0.6681 (0.6681)  time: 2.1273  data: 0.8349  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4536 (0.4543)  evaluator_time: 0.2176 (0.2422)  time: 0.8304  data: 0.0868  max mem: 5143
# Test: Total time: 0:00:13 (0.8343 s / it)
# Averaged stats: model_time: 0.4536 (0.4543)  evaluator_time: 0.2176 (0.2422)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#
#
# Epoch: [29]  [ 0/36]  eta: 0:01:31  lr: 0.000000  loss: 0.1432 (0.1432)  loss_classifier: 0.0608 (0.0608)  loss_box_reg: 0.0740 (0.0740)  loss_objectness: 0.0040 (0.0040)  loss_rpn_box_reg: 0.0044 (0.0044)  time: 2.5295  data: 1.2992  max mem: 5143
# Epoch: [29]  [10/36]  eta: 0:00:33  lr: 0.000000  loss: 0.1670 (0.1855)  loss_classifier: 0.0627 (0.0758)  loss_box_reg: 0.0959 (0.0973)  loss_objectness: 0.0040 (0.0046)  loss_rpn_box_reg: 0.0078 (0.0077)  time: 1.2845  data: 0.1822  max mem: 5143
# Epoch: [29]  [20/36]  eta: 0:00:19  lr: 0.000000  loss: 0.1670 (0.1970)  loss_classifier: 0.0661 (0.0796)  loss_box_reg: 0.0959 (0.1027)  loss_objectness: 0.0042 (0.0069)  loss_rpn_box_reg: 0.0074 (0.0077)  time: 1.1205  data: 0.0473  max mem: 5143
# Epoch: [29]  [30/36]  eta: 0:00:06  lr: 0.000000  loss: 0.1515 (0.1905)  loss_classifier: 0.0660 (0.0774)  loss_box_reg: 0.0803 (0.0982)  loss_objectness: 0.0050 (0.0071)  loss_rpn_box_reg: 0.0065 (0.0078)  time: 1.0827  data: 0.0256  max mem: 5143
# Epoch: [29]  [35/36]  eta: 0:00:01  lr: 0.000000  loss: 0.1686 (0.1895)  loss_classifier: 0.0692 (0.0777)  loss_box_reg: 0.0803 (0.0969)  loss_objectness: 0.0060 (0.0071)  loss_rpn_box_reg: 0.0064 (0.0078)  time: 1.0769  data: 0.0246  max mem: 5143
# Epoch: [29] Total time: 0:00:41 (1.1429 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:33  model_time: 0.5611 (0.5611)  evaluator_time: 0.6675 (0.6675)  time: 2.1141  data: 0.8104  max mem: 5143
# Test:  [15/16]  eta: 0:00:00  model_time: 0.4321 (0.4345)  evaluator_time: 0.2187 (0.2419)  time: 0.8209  data: 0.0977  max mem: 5143
# Test: Total time: 0:00:13 (0.8250 s / it)
# Averaged stats: model_time: 0.4321 (0.4345)  evaluator_time: 0.2187 (0.2419)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
